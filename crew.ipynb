# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM

llm=LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)

# %%
from crewai import Agent, Task, Crew

research_agent=Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent=Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 tasks",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research",
    expected_output="A blog post summary",
    agent=writer_agent,
    content=[task1],
)

crew = Crew(
agents=[research_agent, writer_agent],
tasks=[task1, task2],
verbose=True,
)

crew.kickoff(inputs={"topic":"The future of electrical vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1d348182-6bf3-49ce-b7dc-fd4fd26bc43f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  ID: f62aa582-350c-40ef-aa55-3e5e52b144bc                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 5 interesting and recent facts about the future of electrical vehicles:                               │
# │                                                                                                                 │
# │  *   **Continued Exponential Market Growth:** Global electric car sales are projected to reach 17 million in    │
# │  2024, representing more than one in five new cars sold worldwide. The International Energy Agency (IEA)        │
# │  forecasts that by 2030, nearly one in three cars on the roads in China, and almost one in five in Europe and   │
# │  the United States, will be electric, demonstrating a sustained and rapid global transition.                    │
# │  *   **Solid-State Batteries Poised for Commercialization:** The "holy grail" of EV battery technology,         │
# │  solid-state batteries, are nearing commercial readiness. Companies like Toyota and Nissan are targeting        │
# │  production by 2027-2028, promising significantly increased range (potentially over 1,000 km on a single        │
# │  charge), ultra-fast charging times (e.g., 10-80% in under 10 minutes), and enhanced safety due to the absence  │
# │  of flammable liquid electrolytes.                                                                              │
# │  *   **Vehicle-to-Grid (V2G) Technology Expanding Rapidly:** The role of EVs is evolving beyond                 │
# │  transportation, with Vehicle-to-Grid (V2G) technology allowing them to feed stored energy back into the power  │
# │  grid. This capability helps stabilize grids, integrate more renewable energy sources, and can offer financial  │
# │  incentives to EV owners. The global V2G market is projected for substantial growth, positioning EVs as         │
# │  crucial components of future smart energy systems.                                                             │
# │  *   **Intensified Focus on Battery Recycling and Circular Economy:** As EV adoption surges, so does the        │
# │  demand for critical minerals like lithium, cobalt, and nickel. The future of EVs necessitates a robust         │
# │  circular economy for batteries, with significant investments and technological advancements being made in      │
# │  recycling processes to recover valuable materials, reduce reliance on new mining, and minimize environmental   │
# │  impact. This is becoming a cornerstone of sustainable EV growth.                                               │
# │  *   **Standardization and Ultra-Fast Charging Networks are Becoming Norms:** The charging experience is set    │
# │  to become more seamless and efficient. The widespread adoption of the North American Charging Standard (NACS)  │
# │  by major automakers and charging networks is streamlining compatibility. Concurrently, the global deployment   │
# │  of ultra-fast charging stations (350 kW and above) is accelerating, capable of adding hundreds of miles of     │
# │  range in as little as 15-20 minutes, effectively eliminating range anxiety for most drivers.                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research                                                                                                       │
# │  ID: 6e369935-6712-4e66-bb91-7531f2fe63a8                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is electrifying! Global sales are soaring, projected to hit 17 million in      │
# │  2024, with over one in five new cars being electric. Revolutionary solid-state batteries, promising 1,000 km   │
# │  range and ultra-fast 10-minute charging, are nearing commercialization by 2027. EVs are also transforming      │
# │  into mobile power sources with Vehicle-to-Grid (V2G) technology, helping stabilize energy grids. As demand     │
# │  for critical minerals surges, sustainable battery recycling is paramount. Plus, standardized and ultra-fast    │
# │  charging networks are expanding, making long-distance EV travel convenient.                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research                                                                                                       │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 1d348182-6bf3-49ce-b7dc-fd4fd26bc43f                                                                       │
# │  Final Output: The future of electric vehicles is electrifying! Global sales are soaring, projected to hit 17   │
# │  million in 2024, with over one in five new cars being electric. Revolutionary solid-state batteries,           │
# │  promising 1,000 km range and ultra-fast 10-minute charging, are nearing commercialization by 2027. EVs are     │
# │  also transforming into mobile power sources with Vehicle-to-Grid (V2G) technology, helping stabilize energy    │
# │  grids. As demand for critical minerals surges, sustainable battery recycling is paramount. Plus, standardized  │
# │  and ultra-fast charging networks are expanding, making long-distance EV travel convenient.                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw='The future of electric vehicles is electrifying! Global sales are soaring, projected to hit 17 million in 2024, with over one in five new cars being electric. Revolutionary solid-state batteries, promising 1,000 km range and ultra-fast 10-minute charging, are nearing commercialization by 2027. EVs are also transforming into mobile power sources with Vehicle-to-Grid (V2G) technology, helping stabilize energy grids. As demand for critical minerals surges, sustainable battery recycling is paramount. Plus, standardized and ultra-fast charging networks are expanding, making long-distance EV travel convenient.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles.', expected_output='A bullet list of 3-5 tasks', summary='Find 3-5 interesting and recent facts about The future of...', raw='Here are 5 interesting and recent facts about the future of electrical vehicles:\n\n*   **Continued Exponential Market Growth:** Global electric car sales are projected to reach 17 million in 2024, representing more than one in five new cars sold worldwide. The International Energy Agency (IEA) forecasts that by 2030, nearly one in three cars on the roads in China, and almost one in five in Europe and the United States, will be electric, demonstrating a sustained and rapid global transition.\n*   **Solid-State Batteries Poised for Commercialization:** The "holy grail" of EV battery technology, solid-state batteries, are nearing commercial readiness. Companies like Toyota and Nissan are targeting production by 2027-2028, promising significantly increased range (potentially over 1,000 km on a single charge), ultra-fast charging times (e.g., 10-80% in under 10 minutes), and enhanced safety due to the absence of flammable liquid electrolytes.\n*   **Vehicle-to-Grid (V2G) Technology Expanding Rapidly:** The role of EVs is evolving beyond transportation, with Vehicle-to-Grid (V2G) technology allowing them to feed stored energy back into the power grid. This capability helps stabilize grids, integrate more renewable energy sources, and can offer financial incentives to EV owners. The global V2G market is projected for substantial growth, positioning EVs as crucial components of future smart energy systems.\n*   **Intensified Focus on Battery Recycling and Circular Economy:** As EV adoption surges, so does the demand for critical minerals like lithium, cobalt, and nickel. The future of EVs necessitates a robust circular economy for batteries, with significant investments and technological advancements being made in recycling processes to recover valuable materials, reduce reliance on new mining, and minimize environmental impact. This is becoming a cornerstone of sustainable EV growth.\n*   **Standardization and Ultra-Fast Charging Networks are Becoming Norms:** The charging experience is set to become more seamless and efficient. The widespread adoption of the North American Charging Standard (NACS) by major automakers and charging networks is streamlining compatibility. Concurrently, the global deployment of ultra-fast charging stations (350 kW and above) is accelerating, capable of adding hundreds of miles of range in as little as 15-20 minutes, effectively eliminating range anxiety for most drivers.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: Research interesting facts about the topic: The future of electrical vehicles'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facsts aboyt The future of electrical vehicles.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 tasks\nyou MUST return the actual c ...
